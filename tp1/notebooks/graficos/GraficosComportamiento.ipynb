# %%
import pandas as pd
import numpy as np
import ConfigParser, os
import seaborn as sea
import matplotlib.pyplot as plt

sea.set(font_scale=2)  # crazy big

# %matplotlib inline

# %% [markdown]
# # Teacup
# ## SD vs CD

# %%
tc_sd = pd.read_csv('../tp1/datos/sd_teacup.csv',sep=',', names=['t', 'temp'], skiprows=1)
tc_cd = pd.read_csv('../tp1/datos/cd_teacup.csv',sep='\t+', engine='python', names=['t','var', 'temp'], skiprows=1)


try: 
    del tc_cd['var']
except: pass 
tc_cd['model'] = 'CD'
tc_sd['model'] = 'SD'

tc_cd['medicion'] = np.array(range(0, tc_cd.shape[0]))
tc_sd['medicion'] = np.array(range(0, tc_sd.shape[0]))

def string_t_cd_a_int(val):
    acum = 0
    vals = [int(x) for x in val.strip().split(':')]
    acum = vals[0]*3600 + vals[1] * 60 + vals[2] + vals[3]/1000
    return acum

def string_t_sd_a_int(val):
    return val * 60

tc_sd.t = tc_sd.t.apply(lambda x: string_t_sd_a_int(x))
tc_cd.t = tc_cd.t.apply(lambda x: string_t_cd_a_int(x))

# %%
tc  = pd.concat([tc_sd, tc_cd])

plt.figure(figsize=(15,5))
g=sea.pointplot(data=tc, x='t', y='temp', hue='model')#, dodge=1.5)

# %%
tc_sd = pd.read_csv('../tp1/datos/sd_teacup.csv',sep=',', names=['t', 'temp'], skiprows=1)
tc_cd = pd.read_csv('../tp1/datos/cd_teacup.csv',sep='\t+', engine='python', names=['t','var', 'temp'], skiprows=1)


try: 
    del tc_cd['var']
except: pass 
tc_cd['model'] = 'CD'
tc_sd['model'] = 'SD'

tc_cd['medicion'] = np.array(range(0, tc_cd.shape[0]))
tc_sd['medicion'] = np.array(range(0, tc_sd.shape[0]))

def string_t_cd_a_int(val):
    acum = 0
    vals = val.strip().split(':')
    acum = vals[0]*3600 + vals[1] * 60 + vals[2] + vals[3]
    return acum

def string_t_sd_a_int(val):
    return val * 60

'''
try:
    tc_cd.t = pd.to_datetime(tc_cd.t.str.strip(), format='%H:%M:%S:%f')
    tc_cd.t = tc_cd.t.apply(lambda x: x.strftime("%M:%S:%f"))
    tc_cd.t = tc_cd.t.apply(lambda x: time.mktime(time.strptime(x, "%M:%S:%f")))

    tc_sd.t = tc_sd.t.apply(lambda x: datetime.datetime.fromtimestamp(x))
    tc_sd.t = tc_sd.t.apply(lambda x: x.strftime("%M:%S:%f"))
    tc_sd.t = tc_sd.t.apply(lambda x: time.mktime(time.strptime(x, "%M:%S:%f")))
except: pass
'''
tc_cd.t = tc_cd.t.apply(lambda x: x.strftime("%M:%S:%f"))


tc = pd.concat([tc_sd, tc_cd.iloc[range(0, tc_sd.shape[0], tc_sd.shape[0]/tc_sd.shape[0])]])
tc.t = tc.t + abs(min(tc.t))
#tc = tc.query('t < 30')

plt.figure(figsize=(15,5))
g=sea.pointplot(data=tc, x='medicion', y='temp', hue='model')#, dodge=1.5)
g.set_xticklabels([], rotation=30)
g.set_title(u'Evolución de la temperatura para el modelo TeaCup')
# Out:
# Text(0.5,1,u'Evoluci\xf3n de la temperatura para el modelo TeaCup')

# %%
dest_points = min(tc_sd.shape[0], tc_cd.shape[0])

len(range(0, tc_sd.shape[0], tc_sd.shape[0]/dest_points))
# Out:
# 100

# %%
len(tc_sd)
# Out:
# 100

# %% [markdown]
# ## CD++

# %% [markdown]
# SIR

# %%
sir_sd = pd.read_csv('../tp1/datos/sd_sir.csv', sep=',', names=['t', 'R_SD', 'I_SD', 'S_SD'], skiprows=1)
sir_sd = sir_sd.melt(id_vars='t')
sir_sd.columns = ['t', 'var', 'val']
sir_cd = pd.read_csv('../tp1/datos/cd_sir_10m.tsv',sep='\t+', engine='python', names=['t','var', 'val'], skiprows=1)

sir_cd.t = sir_cd.t.apply(lambda x: string_t_cd_a_int(x))
#sir_sd.t = sir_sd.t.apply(lambda x: string_t_sd_a_int(x))

# %%
sea.set_style("whitegrid")

import matplotlib.ticker as ticker
sir = pd.concat([sir_sd, sir_cd])
sir['var_name'] = sir['var'].str.__getitem__(0)
plt.figure(figsize=(15,5))
g=sea.pointplot(data=sir.query('var_name == "S"'), x='t', y='val', hue='var')
g.xaxis.set_major_locator(ticker.LinearLocator(numticks=5))
g.set_title(u"Evolución para la variable Susceptible en los modelos SD y CD")

plt.figure(figsize=(15,5))
g=sea.pointplot(data=sir.query('var_name == "R"'), x='t', y='val', hue='var')
g.xaxis.set_major_locator(ticker.LinearLocator(numticks=5))
g.set_title(u"Evolución para la variable Recuperandose en los modelos SD y CD")

plt.figure(figsize=(15,5))

g=sea.pointplot(data=sir.query('var_name == "I"'), x='t', y='val', hue='var')
g.xaxis.set_major_locator(ticker.LinearLocator(numticks=5))
g.set_title(u"Evolución para la variable Infectados en los modelos SD y CD")
# Out:
# Text(0.5,1,u'Evoluci\xf3n para la variable Infectados en los modelos SD y CD')

# %%
sir.t
# Out:
# 0         0.00000
# 1         0.03125
# 2         0.06250
# 3         0.09375
# 4         0.12500
# 5         0.15625
# 6         0.18750
# 7         0.21875
# 8         0.25000
# 9         0.28125
# 10        0.31250
# 11        0.34375
# 12        0.37500
# 13        0.40625
# 14        0.43750
# 15        0.46875
# 16        0.50000
# 17        0.53125
# 18        0.56250
# 19        0.59375
# 20        0.62500
# 21        0.65625
# 22        0.68750
# 23        0.71875
# 24        0.75000
# 25        0.78125
# 26        0.81250
# 27        0.84375
# 28        0.87500
# 29        0.90625
#           ...
# 3020    170.00000
# 3021    170.00000
# 3022    170.00000
# 3023    171.00000
# 3024    171.00000
# 3025    171.00000
# 3026    171.00000
# 3027    172.00000
# 3028    172.00000
# 3029    172.00000
# 3030    172.00000
# 3031    173.00000
# 3032    173.00000
# 3033    173.00000
# 3034    173.00000
# 3035    174.00000
# 3036    174.00000
# 3037    174.00000
# 3038    175.00000
# ...

# %%
sir_sd.query('var == "R_SD"').plot(x='t', y='val')

# %%
psd = pd.read_csv('../tp1/datos/sd_sir.csv', sep=',', names=['t', 'R_SD', 'I_SD', 'S_SD'], skiprows=1)
import datetime
psd.t = psd.t.apply(lambda x: datetime.datetime.fromtimestamp(x))
psd.t = psd.t.apply(lambda x: x.strftime("%M:%S:%f"))
psd2 = psd.melt(id_vars='t')
psd2.columns = ['t', 'var', 'val']
psd2['model'] = 'SD'

# %%
sample_ps2 = psd2.pivot_table(index='t', columns=['var']).reset_index().iloc[range(0, 3201, 100)]
sample_ps2.columns = sample_ps2.columns.droplevel()
sample_ps2.columns = [u't', u'I_SD', u'R_SD', u'S_SD']
sample_ps2_melted = sample_ps2.melt('t')
sample_ps2_melted['model'] = 'SD'
sample_ps2_melted.columns = ['t', 'var', 'val', 'model']

# %%
s_cd = p.query('var == "S_CD"')
i_cd = p.query('var == "I_CD"')
i_cd = i_cd.iloc[range(0, i_cd.shape[0], 10)]
r_cd = p.query('var == "R_CD"')
r_cd = r_cd.iloc[range(0, r_cd.shape[0], 5)]

# %%
# Out:
# Index([u't', u'variable', u'value', u'model'], dtype='object')

# %%
g=sea.pointplot(data=sample_ps2_melted, x='t', y='value', hue='variable')

# %%
plt.figure(figsize=(15,5))
g=sea.pointplot(data=psd2.iloc[range(0, psd2.shape[0],10)], x='t', y='val', hue='var')

# %%
p = pd.read_csv('../tp1/datos/cd_sir_10m.tsv',sep='\t+', engine='python', names=['t','var', 'val'], skiprows=1)

p['model'] = 'CD'
p.t = pd.to_datetime(p.t.str.strip(), format='%H:%M:%S:%f')
p.t = p.t.apply(lambda x: x.strftime("%M:%S:%f"))

# %%
plt.figure(figsize=(15,5))
g=sea.pointplot(data=p.iloc[range(0, p.shape[0],10)], x='t', y='val', hue='var')
#g.set(xticklabels=[])
locs, labels = plt.xticks()
g.set_xticklabels(labels, rotation=30)
g.set_title('Evolucion de la temperatura para el modelo TeaCup')
#g.legend_.remove()
# Out:
# Text(0.5,1,u'Evolucion de la temperatura para el modelo TeaCup')

# %%
cd_sd_sir = pd.concat([p.iloc[range(0, p.shape[0], p.shape[0] / 200)],
                       psd2.iloc[range(0, psd2.shape[0], psd2.shape[0] / 200)]
])

# %%
psd2.iloc[range(0, psd2.shape[0], psd2.shape[0] / 200)].shape
p.iloc[range(0, p.shape[0], p.shape[0] / 200)].shape
# Out:
# (204, 4)

# %%
g=sea.pointplot(data=cd_sd_sir.query('model == "SD"'), x='t', y='val', hue='var')

# %%
g=sea.pointplot(data=psd2.iloc[range(0, psd2.shape[0], psd2.shape[0] / 200)], x='t', y='val', hue='var')
#sub.query("val > 200 and val < 250 and (var == 'I_CD' or var == 'I_SD')")

# %%
sub = cd_sd_sir.iloc[range(0, cd_sd_sir.shape[0], 10)]
g = sea.FacetGrid(sub,  row="var", hue='model')
g = g.map(plt.scatter, "t", 'val')

# %%
plt.figure(figsize=(15,5))
g=sea.pointplot(data=cd_sd_sir.iloc[range(0, cd_sd_sir.shape[0],100),:], x='t', y='val', hue='var')
g.set(xticklabels=[])
locs, labels = plt.xticks()
g.set_xticklabels(labels, rotation=30)
g.set_title('Evolucion de la temperatura para el modelo TeaCup')
#g.legend_.remove()
# Out:
# Text(0.5,1,u'Evolucion de la temperatura para el modelo TeaCup')

# %%
plt.figure(figsize=(15,5))
g=sea.pointplot(data=cd_sd_sir.query('model == "SD"'), x='t', y='val', hue='var')
g.set(xticklabels=[])
locs, labels = plt.xticks()
g.set_xticklabels(labels, rotation=30)
g.set_title('Evolucion de la temperatura para el modelo TeaCup')
#g.legend_.remove()
# Out:
# Text(0.5,1,u'Evolucion de la temperatura para el modelo TeaCup')

# %%
pd.DataFrame({'cd_t': cd_sd_sir.query('model == "CD"').t, 'sd_t': 
              cd_sd_sir.query('model == "SD"').t})#.plot(x='cd_t', y='sd_t')
# Out:
#               cd_t          sd_t
# 0     00:00:000000  00:00:000000
# 1     00:00:000000  00:00:031250
# 2     00:00:000000  00:00:062500
# 3     00:00:000000  00:00:093750
# 4     00:00:000000  00:00:125000
# 5     00:00:000000  00:00:156250
# 6     00:00:000000  00:00:187500
# 7     00:00:001000  00:00:218750
# 8     00:00:001000  00:00:250000
# 9     00:00:001000  00:00:281250
# 10    00:00:001000  00:00:312500
# 11    00:00:001000  00:00:343750
# 12    00:00:002000  00:00:375000
# 13    00:00:002000  00:00:406250
# 14    00:00:002000  00:00:437500
# 15    00:00:002000  00:00:468750
# 16    00:00:002000  00:00:500000
# 17    00:00:003000  00:00:531250
# 18    00:00:003000  00:00:562500
# 19    00:00:003000  00:00:593750
# 20    00:00:003000  00:00:625000
# 21    00:00:003000  00:00:656250
# 22    00:00:004000  00:00:687500
# 23    00:00:004000  00:00:718750
# 24    00:00:004000  00:00:750000
# 25    00:00:004000  00:00:781250
# 26    00:00:004000  00:00:812500
# ...
